# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

# %%
# Create synthetic binary classification data with 2 features
X, y = make_classification(n_samples=200, 
                           n_features=2, 
                           n_informative=2, 
                           n_redundant=0,
                           n_clusters_per_class=1,
                           random_state=42)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.DataFrame(X, columns=['data1', 'data2'])
df['output'] = y

# %%
df.head()
# Out:
#       data1     data2  output
# 0 -0.872929  0.013042       1
# 1  1.312935  2.770534       1
# 2  2.340428  2.420996       1
# 3  2.294548 -0.404380       1
# 4  0.944105  0.477241       1

# %%
df.shape
# Out:
# (200, 3)

# %%
plt.Figure(figsize=(5, 4))
sns.scatterplot(data=df, x='data1', y='data2', hue='output')
plt.show()

# %%
x = df.iloc[:,:-1]
y = df['output']

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=3)
pf.fit(x)
x = pd.DataFrame(pf.transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 85.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
#plt.figure(figsize=(10, 6))
#plot_decision_regions(X=x.to_numpy(), y=y.to_numpy(), clf=lr, legend=2)
#plt.show()

# %%
plt.figure(figsize=(10, 6))
plot_decision_regions(x=x.to_numpy() , y=y.to_numpy(), clf=lr, legend=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plot_decision_regions(x=x.to_numpy() , y=y.to_numpy(), clf=lr, legend=2)
#       3 plt.show()
#
# TypeError: plot_decision_regions() got an unexpected keyword argument 'x'. Did you mean 'X'?
